# %% [markdown]
# # Concating Two Data Frames

# %%
import pandas as pd

india_weather = pd.DataFrame({
        "city":["mumbai","delhi","banglore"],
        "temperature":[32,39,42],
        "humidity":[80,60,78]
})

india_weather
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           39        60
# 2  banglore           42        78

# %%
US_weather = pd.DataFrame({
        "city":["new york","chicago","orlando"],
        "temperature":[21,14,35],
        "humidity":[68,65,75]
})
US_weather
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df = pd.concat([india_weather,US_weather])
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           39        60
# 2  banglore           42        78
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df = pd.concat([india_weather,US_weather],ignore_index=True)
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           39        60
# 2  banglore           42        78
# 3  new york           21        68
# 4   chicago           14        65
# 5   orlando           35        75

# %%
df = pd.concat([india_weather,US_weather],keys=["India","US"])
df
# Out:
#              city  temperature  humidity
# India 0    mumbai           32        80
#       1     delhi           39        60
#       2  banglore           42        78
# US    0  new york           21        68
#       1   chicago           14        65
#       2   orlando           35        75

# %%
df.loc["US"]
df.loc["India"]
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           39        60
# 2  banglore           42        78

# %%
temp_df = pd.DataFrame({
        "city":["mumbai","delhi","banglore"],
        "temperature":[32,39,42]},index=[0,1,2])
temp_df
# Out:
#        city  temperature
# 0    mumbai           32
# 1     delhi           39
# 2  banglore           42

# %%
windspeed_df = pd.DataFrame({
        "city":["mumbai","delhi"],
        "windspeed":[7,12]},index=[0,1])
windspeed_df
# Out:
#      city  windspeed
# 0  mumbai          7
# 1   delhi         12

# %%
df = pd.concat([temp_df,windspeed_df])
df
# Out:
#        city  temperature  windspeed
# 0    mumbai         32.0        NaN
# 1     delhi         39.0        NaN
# 2  banglore         42.0        NaN
# 0    mumbai          NaN        7.0
# 1     delhi          NaN       12.0

# %%
df = pd.concat([temp_df,windspeed_df],axis=1)
df
# Out:
#        city  temperature    city  windspeed
# 0    mumbai           32  mumbai        7.0
# 1     delhi           39   delhi       12.0
# 2  banglore           42     NaN        NaN
