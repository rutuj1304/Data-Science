# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [1, 2, 3, 4, 5, 6, 7 ]
y = [40,51,55,89,49,64,87]
plt.xlabel("Day")
plt.ylabel("Temperature")
plt.title("Weather")
plt.plot(x,y,"k")

# %%
plt.plot(x,y,color="blue",marker="+",linestyle=" ")

# %%
plt.plot(x,y,color="blue",marker="+",linestyle=" ",markersize=15)
